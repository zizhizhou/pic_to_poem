# %%
from tkinter import *
from tkinter import filedialog
import tkinter.messagebox
import webbrowser as web
from PIL import Image,ImageTk
import cifar100vgg as cfvg
import os
import train as tr


def main():
    
    def selectImafile():
        global sfname 
        sfname = filedialog.askopenfilename(title='选择图片', filetypes=[('JPG', '*.jpg'), ('PNG', '*.png'),('JPEG','*.jpeg')])
        print(sfname)
        text1.insert(INSERT,sfname)
        if sfname!=None:
                path=sfname
                outfile=cfvg.resize_image(path,400,200)
                load = Image.open(outfile)
                render = ImageTk.PhotoImage(load)
                img = tkinter.Label(image=render)
                img.image = render
                img.place(x=20, y=140)
                os.remove(outfile)


    def closeThisWindow():
        root.destroy()


    
    def choosepic(path_):
        #path.set(path_)
        img_open = Image.open(path_)
        img=ImageTk.PhotoImage(img_open)
        l1=Label(root)
        l1.config(image=img)
        l1.image=img
    
    def change_poem(poem_list):
        p = list(poem_list[0])
        p.insert(6, '\n')
        p.insert(14, '\n')
        p.insert(22, '\n')
        poems = ''.join(p)
        poem=tkinter.Message(root,bg="#B0E0E6",text=poems, 
                     width=200,font=('华文新魏',17))
        poem.pack()
        poem.place(x=500,y=150)
        tmp=poem_list.pop(0)
        poem_list.append(tmp)
    def print_poem():
        if sfname!=None:
            path=sfname
            label=cfvg.pic_to_label(path)
            poem_list=tr.label_poem(label)
            change_poem(poem_list)
            #poem=tkinter.Message(root,bg="#B0E0E6",text=poem_list[0], 
            #                    width=200,font=('华文新魏',17))
            button4=Button(root,text='下一首',width=10,command=lambda:change_poem(poem_list),font=('华文楷体',11),bg="#A9A9A9")
            button4.place(x=670,y=200)

        else:
            tkinter.messagebox.showinfo('提示','请先选择一张图片！')
            

    def open_link():
        web.open('https://www.boater.cn/')   
    #初始化
    root=Tk()
    root["background"]="#B0E0E6"
    #设置窗体标题
    root.title('看图作诗 ver0.10')

    #设置窗口大小和位置
    root.geometry('800x400+570+200')




    label1=Label(root,font=('华文楷体',14),text='请选择图片:',bg="#B0E0E6")
    text1=Entry(root,bg='white',width=45,font=('微软雅黑',10))
    button1=Button(root,text='浏览',width=8,command=selectImafile,font=('华文楷体',12),bg="#D2B48C")
    button2=Button(root,text='作诗',width=8,command=print_poem,font=('华文楷体',12),bg="#FFDAB9")
    button3=Button(root,text='退出程序',width=8,command=closeThisWindow,font=('华文楷体',12),bg="#A9A9A9")
    link=Button(root,text='访问主页',bg='#B0C4DE',width=8,command=open_link,font=('楷体',10))
    
    
    """
    label1.pack()
    text1.pack()
    button1.pack()
    button2.pack()
    button3.pack() 
    """
    label1.place(x=90,y=30)
    text1.place(x=200,y=33)
    button1.place(x=580,y=25)
    button2.place(x=250,y=80)
    button3.place(x=430,y=80)
    link.place(x=670,y=360)
    root.attributes("-toolwindow", 1)
    root.mainloop() 

if __name__=="__main__":
    main()
# Out:
# Using TensorFlow backend.
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# e:\mniconda\envs\test\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:/Users/28278/OneDrive/图片/illust_44873217_20180613_103844.jpg
# 鱼钓船鸟
# genrating...
# INFO:tensorflow:Restoring parameters from checkpoints_key/poetry-25999
# restored checkpoints_key/poetry-25999
# 鱼钓船鸟
# genrating...
# INFO:tensorflow:Restoring parameters from checkpoints_key/poetry-25999
# restored checkpoints_key/poetry-25999
# 鱼钓船鸟
# genrating...
# INFO:tensorflow:Restoring parameters from checkpoints_key/poetry-25999
# restored checkpoints_key/poetry-25999
# 鱼钓船鸟
# genrating...
# INFO:tensorflow:Restoring parameters from checkpoints_key/poetry-25999
# restored checkpoints_key/poetry-25999
# 鱼钓船鸟
# genrating...
# INFO:tensorflow:Restoring parameters from checkpoints_key/poetry-25999
# restored checkpoints_key/poetry-25999
# 生成5首诗
#
# 扰哉耶沈客，
# 茶留八客羁。
# 牢云一处去，
# 归去不可相。
#
# 家曲乌飞散，
# 师游云羽屏。
# 渔夫鱼在远，
# 酒帽道啼钩。
#
# 花屐已归钟，
# 看桥经阁朵。
# 此人不得得，
# 处处与鱼相。
#
# 昨日离鸣竹，
# 新斜昼来眠。
# 枯童不驱袂，
# 舒听送牛行。
#
# 我上隔青陵，
# 室莲天未试。
# 夫恨唯谆军，
# 损春归往看。

# %%
# !pip install gensim
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: gensim in e:\mniconda\envs\test\lib\site-packages (3.8.2)
# Requirement already satisfied: smart-open>=1.8.1 in e:\mniconda\envs\test\lib\site-packages (from gensim) (2.0.0)
# Requirement already satisfied: six>=1.5.0 in e:\mniconda\envs\test\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: numpy>=1.11.3 in e:\mniconda\envs\test\lib\site-packages (from gensim) (1.18.3)
# Requirement already satisfied: scipy>=1.0.0 in e:\mniconda\envs\test\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: requests in e:\mniconda\envs\test\lib\site-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied: boto3 in e:\mniconda\envs\test\lib\site-packages (from smart-open>=1.8.1->gensim) (1.13.3)
# Requirement already satisfied: boto in e:\mniconda\envs\test\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\mniconda\envs\test\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in e:\mniconda\envs\test\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mniconda\envs\test\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in e:\mniconda\envs\test\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.9)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in e:\mniconda\envs\test\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in e:\mniconda\envs\test\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.5)
# Requirement already satisfied: botocore<1.17.0,>=1.16.3 in e:\mniconda\envs\test\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.16.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in e:\mniconda\envs\test\lib\site-packages (from botocore<1.17.0,>=1.16.3->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in e:\mniconda\envs\test\lib\site-packages (from botocore<1.17.0,>=1.16.3->boto3->smart-open>=1.8.1->gensim) (2.8.1)

# %%
import cifar100vgg as cfvg
cfvg.get_labels()
# Out:
# ['apple',
#  'aquarium_fish',
#  'baby',
#  'bear',
#  'beaver',
#  'bed',
#  'bee',
#  'beetle',
#  'bicycle',
#  'bottle',
#  'bowl',
#  'boy',
#  'bridge',
#  'bus',
#  'butterfly',
#  'camel',
#  'can',
#  'castle',
#  'caterpillar',
#  'cattle',
#  'chair',
#  'chimpanzee',
#  'clock',
#  'cloud',
#  'cockroach',
#  'couch',
#  'crab',
#  'crocodile',
#  'cup',
#  'dinosaur',
#  'dolphin',
#  'elephant',
#  'flatfish',
#  'forest',
#  'fox',
#  'girl',
#  'hamster',
#  'house',
#  'kangaroo',
#  'keyboard',
#  'lamp',
#  'lawn_mower',
#  'leopard',
#  'lion',
#  'lizard',
#  'lobster',
#  'man',
#  'maple_tree',
#  'motorcycle',
#  'mountain',
#  'mouse',
#  'mushroom',
#  'oak_tree',
#  'orange',
#  'orchid',
#  'otter',
#  'palm_tree',
#  'pear',
#  'pickup_truck',
#  'pine_tree',
#  'plain',
#  'plate',
#  'poppy',
#  'porcupine',
#  'possum',
#  'rabbit',
#  'raccoon',
#  'ray',
#  'road',
#  'rocket',
#  'rose',
#  'sea',
#  'seal',
#  'shark',
#  'shrew',
#  'skunk',
#  'skyscraper',
#  'snail',
#  'snake',
#  'spider',
#  'squirrel',
#  'streetcar',
#  'sunflower',
#  'sweet_pepper',
#  'table',
#  'tank',
#  'telephone',
#  'television',
#  'tiger',
#  'tractor',
#  'train',
#  'trout',
#  'tulip',
#  'turtle',
#  'wardrobe',
#  'whale',
#  'willow_tree',
#  'wolf',
#  'woman',
#  'worm']

# %%
# !pip list
# Out:
# Package             Version
# ------------------- -------------------
# absl-py             0.9.0
# astor               0.8.1
# attrs               19.3.0
# backcall            0.1.0
# bleach              1.5.0
# certifi             2020.4.5.1
# colorama            0.4.3
# cycler              0.10.0
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# gast                0.3.3
# grpcio              1.28.1
# h5py                2.10.0
# html5lib            0.9999999
# importlib-metadata  1.6.0
# ipykernel           5.2.1
# ipython             7.14.0
# ipython-genutils    0.2.0
# ipywidgets          7.5.1
# jedi                0.17.0
# Jinja2              2.11.2
# jsonschema          3.2.0
# jupyter             1.0.0
# jupyter-client      6.1.3
# jupyter-console     6.1.0
# jupyter-core        4.6.3
# Keras               2.2.4
# Keras-Applications  1.0.8
# Keras-Preprocessing 1.1.0
# kiwisolver          1.2.0
# Markdown            3.2.1
# MarkupSafe          1.1.1
# matplotlib          3.2.1
# mistune             0.8.4
# nbconvert           5.6.1
# nbformat            5.0.6
# notebook            6.0.3
# numpy               1.18.3
# packaging           20.3
# pandocfilters       1.4.2
# parso               0.7.0
# pickleshare         0.7.5
# Pillow              7.1.2
# pip                 20.0.2
# prometheus-client   0.7.1
# prompt-toolkit      3.0.5
# protobuf            3.11.3
# Pygments            2.6.1
# pyparsing           2.4.7
# pyrsistent          0.16.0
# python-dateutil     2.8.1
# pywin32             227
# pywinpty            0.5.7
# PyYAML              5.3.1
# pyzmq               19.0.0
# qtconsole           4.7.3
# QtPy                1.9.0
# scipy               1.4.1
# Send2Trash          1.5.0
# setuptools          46.1.3.post20200330
# six                 1.14.0
# tensorboard         1.8.0
# tensorflow          1.8.0
# tensorflow-gpu      1.8.0
# termcolor           1.1.0
# terminado           0.8.3
# testpath            0.4.4
# tornado             6.0.4
# traitlets           4.3.3
# wcwidth             0.1.9
# webencodings        0.5.1
# Werkzeug            1.0.1
# wheel               0.34.2
# widgetsnbextension  3.5.1
# wincertstore        0.2
# zipp                3.1.0
